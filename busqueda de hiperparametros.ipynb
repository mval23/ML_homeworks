# %% [markdown]
# # Taller de búsqueda de hiperparámetros
#
# En este taller vamos a explorar la búsqueda de hiperparámetros de manera automática.

# %%
# !pip install numpy scikit-learn pandas matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\maria\.conda\envs\ceramics\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\maria\.conda\envs\ceramics\lib\site-packages (1.7.0)
# Requirement already satisfied: pandas in c:\users\maria\.conda\envs\ceramics\lib\site-packages (2.3.1)
# Requirement already satisfied: matplotlib in c:\users\maria\.conda\envs\ceramics\lib\site-packages (3.10.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from matplotlib) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
X, y = load_breast_cancer(return_X_y=True)

# %%
test_size=0.25
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

# %% [markdown]
# ### **Ejemplo 1**
# Encuentra los mejores hiperparámetros usando `GridSearchCV`

# %%
clf = DecisionTreeClassifier()

# define los valores que usarás en la búsqueda del
# hiperparametro C
param_grid = {
    "max_depth": (3, 6, 12, 18),
    "min_samples_leaf": (1, 2, 3),
    "criterion": ["gini", "entropy"]
}

# %% [markdown]
# Primero exploremos un poco el dataset

# %%
n_samples = X.shape[0]
n_features = X.shape[1]
n_benign = np.sum(y == 1)
n_malignant = np.sum(y == 0)

perc_benign = n_benign / n_samples * 100
perc_malignant = n_malignant / n_samples * 100

print("Resumen del conjunto de datos de cancer de mama:")
print(f"Total de muestras: {n_samples}")
print(f"Número de características: {n_features}")
print("\nClases objetivo:")
print(f"0 = Maligno: {n_malignant} muestras ({perc_malignant:.1f}%)")
print(f"1 = Benigno: {n_benign} muestras ({perc_benign:.1f}%)")
# Out:
# Resumen del conjunto de datos de cancer de mama:
# Total de muestras: 569
# Número de características: 30
#
# Clases objetivo:
# 0 = Maligno: 212 muestras (37.3%)
# 1 = Benigno: 357 muestras (62.7%)

# %% [markdown]
# Usamos scoring="f1" en Grid Search porque el dataset está ligeramente desbalanceado y nos interesa que el modelo tenga buen rendimiento tanto en casos benignos como malignos. La métrica F1 permite equilibrar precisión y recall, lo cual es clave en contextos médicos donde un falso negativo puede ser más grave que un falso positivo.

# %%
# Utiliza GridSearchCV
gs = GridSearchCV(clf, param_grid, cv=5, scoring='f1', verbose=1)

t0 = time.time()
gs.fit(X_train, y_train)
print("Tiempo de búsqueda: {:.3f}s".format(time.time() - t0))
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Tiempo de búsqueda: 0.599s

# %% [markdown]
# podemos ver que el atributo `cv_results_` nos entrega los resultados de toda la búsqueda.

# %%
dir(gs)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_refit_for_multimetric',
#  '_check_scorers_accept_sample_weight',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_format_results',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params_html',
#  '_get_routed_params_for_fit',
#  '_get_scorers',
#  '_html_repr',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_run_search',
#  '_select_best_index',
#  '_sk_visual_block_',
#  '_validate_params',
#  'best_estimator_',
#  'best_index_',
#  'best_params_',
#  'best_score_',
#  'classes_',
#  'cv',
#  'cv_results_',
#  'decision_function',
#  'error_score',
#  'estimator',
#  'fit',
#  'get_metadata_routing',
#  'get_params',
#  'inverse_transform',
#  'multimetric_',
#  'n_features_in_',
#  'n_jobs',
#  'n_splits_',
#  'param_grid',
#  'pre_dispatch',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'refit',
#  'refit_time_',
#  'return_train_score',
#  'score',
#  'score_samples',
#  'scorer_',
#  'scoring',
#  'set_params',
#  'transform',
#  'verbose']

# %%
resultados = pd.DataFrame(gs.cv_results_)
display(resultados)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000496      0.000993         0.003524        0.006345
# 1        0.000649      0.001299         0.002586        0.004708
# 2        0.004946      0.004956         0.001028        0.000037
# 3        0.002343      0.001989         0.000397        0.000486
# 4        0.000425      0.000850         0.006259        0.007668
# 5        0.000000      0.000000         0.000000        0.000000
# 6        0.006431      0.007876         0.000000        0.000000
# 7        0.006362      0.007792         0.000000        0.000000
# 8        0.001101      0.002202         0.003428        0.006363
# 9        0.003132      0.006264         0.000000        0.000000
# 10       0.006346      0.007200         0.000000        0.000000
# 11       0.003452      0.006314         0.000481        0.000962
# 12       0.003267      0.006282         0.000000        0.000000
# 13       0.003733      0.007466         0.000262        0.000524
# 14       0.003369      0.006160         0.002591        0.005183
# 15       0.003197      0.006394         0.000000        0.000000
# 16       0.000261      0.000522         0.006339        0.007763
# 17       0.000000      0.000000         0.000000        0.000000
# 18       0.006441      0.007889         0.000000        0.000000
# 19       0.006782      0.008335         0.000000        0.000000
# 20       0.003865      0.005539         0.000000        0.000000
# 21       0.006720      0.006142         0.000183        0.000365
# 22       0.003400      0.005819         0.000151        0.000302
# 23       0.000148      0.000296         0.005858        0.007181
#
#    param_criterion  param_max_depth  param_min_samples_leaf  \
# 0             gini                3                       1
# 1             gini                3                       2
# 2             gini                3                       3
# 3             gini                6                       1
# 4             gini                6                       2
# 5             gini                6                       3
# 6             gini               12                       1
# 7             gini               12                       2
# 8             gini               12                       3
# 9             gini               18                       1
# 10            gini               18                       2
# 11            gini               18                       3
# 12         entropy                3                       1
# 13         entropy                3                       2
# 14         entropy                3                       3
# 15         entropy                6                       1
# 16         entropy                6                       2
# 17         entropy                6                       3
# 18         entropy               12                       1
# 19         entropy               12                       2
# 20         entropy               12                       3
# 21         entropy               18                       1
# 22         entropy               18                       2
# 23         entropy               18                       3
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': 3, 'min_sam...           0.932039
# 1   {'criterion': 'gini', 'max_depth': 3, 'min_sam...           0.923077
# 2   {'criterion': 'gini', 'max_depth': 3, 'min_sam...           0.921569
# 3   {'criterion': 'gini', 'max_depth': 6, 'min_sam...           0.914286
# 4   {'criterion': 'gini', 'max_depth': 6, 'min_sam...           0.912621
# 5   {'criterion': 'gini', 'max_depth': 6, 'min_sam...           0.942308
# 6   {'criterion': 'gini', 'max_depth': 12, 'min_sa...           0.903846
# 7   {'criterion': 'gini', 'max_depth': 12, 'min_sa...           0.910891
# 8   {'criterion': 'gini', 'max_depth': 12, 'min_sa...           0.942308
# 9   {'criterion': 'gini', 'max_depth': 18, 'min_sa...           0.901961
# 10  {'criterion': 'gini', 'max_depth': 18, 'min_sa...           0.910891
# 11  {'criterion': 'gini', 'max_depth': 18, 'min_sa...           0.942308
# 12  {'criterion': 'entropy', 'max_depth': 3, 'min_...           0.932039
# 13  {'criterion': 'entropy', 'max_depth': 3, 'min_...           0.932039
# 14  {'criterion': 'entropy', 'max_depth': 3, 'min_...           0.942308
# 15  {'criterion': 'entropy', 'max_depth': 6, 'min_...           0.934579
# 16  {'criterion': 'entropy', 'max_depth': 6, 'min_...           0.934579
# 17  {'criterion': 'entropy', 'max_depth': 6, 'min_...           0.962264
# 18  {'criterion': 'entropy', 'max_depth': 12, 'min...           0.962264
# 19  {'criterion': 'entropy', 'max_depth': 12, 'min...           0.952381
# 20  {'criterion': 'entropy', 'max_depth': 12, 'min...           0.962264
# 21  {'criterion': 'entropy', 'max_depth': 18, 'min...           0.954128
# 22  {'criterion': 'entropy', 'max_depth': 18, 'min...           0.903846
# 23  {'criterion': 'entropy', 'max_depth': 18, 'min...           0.962264
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.942308           0.952381           0.934579
# 1            0.942308           0.952381           0.943396
# 2            0.962264           0.961538           0.934579
# 3            0.943396           0.943396           0.943396
# 4            0.943396           0.962264           0.934579
# 5            0.971963           0.961538           0.934579
# 6            0.962264           0.962264           0.943396
# 7            0.962264           0.941176           0.942308
# 8            0.932039           0.961538           0.934579
# 9            0.962264           0.971963           0.952381
# 10           0.933333           0.952381           0.942308
# 11           0.962264           0.961538           0.934579
# 12           0.962264           0.952381           0.927273
# 13           0.962264           0.952381           0.927273
# 14           0.962264           0.952381           0.927273
# 15           0.962264           0.941176           0.962264
# 16           0.952381           0.951456           0.943396
# 17           0.962264           0.951456           0.934579
# 18           0.952381           0.941176           0.953271
# 19           0.981481           0.951456           0.952381
# 20           0.932039           0.951456           0.944444
# 21           0.952381           0.951456           0.953271
# 22           0.952381           0.951456           0.952381
# 23           0.952381           0.951456           0.934579
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.936937         0.939649        0.007213               21
# 1            0.936937         0.939620        0.009646               22
# 2            0.945455         0.945081        0.015680               13
# 3            0.954128         0.939721        0.013379               20
# 4            0.935780         0.937728        0.015989               23
# 5            0.954128         0.952903        0.013322                4
# 6            0.954128         0.945180        0.021797               12
# 7            0.944444         0.940217        0.016548               19
# 8            0.954128         0.944919        0.011319               14
# 9            0.954128         0.948539        0.024301               10
# 10           0.944444         0.936672        0.014246               24
# 11           0.954128         0.950964        0.010890                6
# 12           0.936937         0.942179        0.013115               18
# 13           0.945455         0.943882        0.012874               17
# 14           0.936937         0.944232        0.012133               16
# 15           0.945455         0.949148        0.011256                9
# 16           0.953271         0.947017        0.007147               11
# 17           0.954128         0.952938        0.010145                3
# 18           0.962963         0.954411        0.007942                2
# 19           0.962963         0.960133        0.011483                1
# 20           0.962963         0.950633        0.011593                8
# 21           0.944444         0.951136        0.003462                5
# 22           0.962963         0.944605        0.020814               15
# 23           0.953271         0.950790        0.008984                7

# %% [markdown]
# Lo más importante es extraer los hiperparámetros del modelo que mejor error en de validación sacaron

# %%
gs.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 2}

# %% [markdown]
# También es posible el mejor resultado en la métrica usada

# %%
gs.best_score_
# Out:
# 0.9601325319771922

# %% [markdown]
# Finalmente, es posible extraer directamente un estimador que que ha sido creado con los mejores hiperparámetros.

# %%
gs.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=12, min_samples_leaf=2)

# %% [markdown]
# Evaluar el mejor modelo en el conjunto de prueba

# %%
mejor_modelo = gs.best_estimator_
y_pred = mejor_modelo.predict(X_test)
print("Accuracy en test:", accuracy_score(y_test, y_pred))
print("F1 Score en test:", f1_score(y_test, y_pred))
# Out:
# Accuracy en test: 0.9230769230769231
# F1 Score en test: 0.9378531073446328

# %% [markdown]
# ### **Ejemplo 2**
# La clase `RandomizedSearchCV` se puede usar casi de la misma manera, solo que esta vez se debe escoger un número de combinaciones a evaluar; las cuales se escogeran de manera aleatoria.

# %%
clf = DecisionTreeClassifier()

# define los valores que usarás en la búsqueda del
# hiperparametro C
param_dist = {
    "max_depth": (3, 6, 12, 18),
    "min_samples_leaf": (1, 2, 3),
    "criterion": ["gini", "entropy"]
}

# Utiliza RandomizedSearchCV
rs = RandomizedSearchCV(
    estimator=clf,
    param_distributions=param_dist,
    n_iter=10,
    cv=5,
    scoring="accuracy",
    random_state=42,
    verbose=1
)
t0 = time.time()
rs.fit(X_train, y_train)
print("Tiempo de búsqueda: {:.3f}s".format(time.time() - t0))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Tiempo de búsqueda: 0.214s

# %%
rs.best_score_
# Out:
# 0.9460465116279071

# %%
print("Mejores parámetros encontrados:", rs.best_params_)
# Out:
# Mejores parámetros encontrados: {'min_samples_leaf': 1, 'max_depth': 12, 'criterion': 'entropy'}

# %% [markdown]
# Evaluar el modelo encontrado por RandomizedSearchCV

# %%
mejor_modelo_rs = rs.best_estimator_
y_pred_rs = mejor_modelo_rs.predict(X_test)

print("Accuracy en test:", accuracy_score(y_test, y_pred_rs))
print("F1 Score en test:", f1_score(y_test, y_pred_rs))
# Out:
# Accuracy en test: 0.9440559440559441
# F1 Score en test: 0.9555555555555556

# %% [markdown]
# Podemos ver que aunque se demoró mucho menos, el resultado no es tan bueno.

# %% [markdown]
# ### Búsqueda de hiperparámetros usando Optuna
#
# Optuna es una biblioteca moderna y eficiente para la optimización automática de hiperparámetros. A diferencia de GridSearchCV o RandomizedSearchCV, utiliza técnicas de búsqueda más inteligentes, como optimización bayesiana, para encontrar buenos resultados con menos combinaciones.

# %%
# !pip install --upgrade nbformat ipython plotly optuna
# Out:
# Requirement already satisfied: nbformat in c:\users\maria\.conda\envs\ceramics\lib\site-packages (5.10.4)
# Requirement already satisfied: ipython in c:\users\maria\.conda\envs\ceramics\lib\site-packages (9.4.0)
# Requirement already satisfied: plotly in c:\users\maria\.conda\envs\ceramics\lib\site-packages (6.2.0)
# Requirement already satisfied: optuna in c:\users\maria\.conda\envs\ceramics\lib\site-packages (4.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from nbformat) (4.24.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: colorama in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from ipython) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from ipython) (4.12.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from plotly) (1.46.0)
# Requirement already satisfied: packaging in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from plotly) (24.2)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from optuna) (1.16.4)
# Requirement already satisfied: colorlog in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from jsonschema>=2.6->nbformat) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# Requirement already satisfied: wcwidth in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: greenlet>=1 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from stack_data->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from stack_data->ipython) (0.2.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\maria\.conda\envs\ceramics\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
import optuna
import optuna.visualization as vis
import plotly.io as pio
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Definimos la función objetivo que Optuna utilizará para evaluar diferentes combinaciones de hiperparámetros. Cada combinación será evaluada usando validación cruzada y la métrica F1.

# %%
# Definimos la función objetivo
def objective(trial):
    max_depth = trial.suggest_int("max_depth", 2, 20)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 5)
    criterion = trial.suggest_categorical("criterion", ["gini", "entropy"])
    
    clf = DecisionTreeClassifier(
        max_depth=max_depth,
        min_samples_leaf=min_samples_leaf,
        criterion=criterion,
        random_state=42
    )

    score = cross_val_score(clf, X_train, y_train, cv=5, scoring="accuracy")
    return score.mean()

# %% [markdown]
# Ahora creamos un estudio y permitimos que Optuna explore 30 combinaciones diferentes de hiperparámetros. Medimos también el tiempo que tarda en ejecutarse.

# %%
study = optuna.create_study(direction="maximize")
t0 = time.time()
study.optimize(objective, n_trials=30)
print("Tiempo de búsqueda: {:.3f}s".format(time.time() - t0))
# Out:
# [I 2025-07-12 22:11:37,362] A new study created in memory with name: no-name-8770198c-a48a-4ac2-9eb8-0acc4c3675b9
# [I 2025-07-12 22:11:37,391] Trial 0 finished with value: 0.941340629274966 and parameters: {'max_depth': 8, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,425] Trial 1 finished with value: 0.941313269493844 and parameters: {'max_depth': 7, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,439] Trial 2 finished with value: 0.9412585499316005 and parameters: {'max_depth': 5, 'min_samples_leaf': 5, 'criterion': 'entropy'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,477] Trial 3 finished with value: 0.934281805745554 and parameters: {'max_depth': 9, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,505] Trial 4 finished with value: 0.9225991792065663 and parameters: {'max_depth': 16, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,525] Trial 5 finished with value: 0.9319562243502052 and parameters: {'max_depth': 16, 'min_samples_leaf': 4, 'criterion': 'gini'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,559] Trial 6 finished with value: 0.9412585499316005 and parameters: {'max_depth': 14, 'min_samples_leaf': 5, 'criterion': 'entropy'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,588] Trial 7 finished with value: 0.9273050615595075 and parameters: {'max_depth': 12, 'min_samples_leaf': 5, 'criterion': 'gini'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,606] Trial 8 finished with value: 0.9365800273597813 and parameters: {'max_depth': 19, 'min_samples_leaf': 4, 'criterion': 'entropy'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,641] Trial 9 finished with value: 0.941313269493844 and parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,678] Trial 10 finished with value: 0.927250341997264 and parameters: {'max_depth': 3, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,715] Trial 11 finished with value: 0.941313269493844 and parameters: {'max_depth': 7, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,757] Trial 12 finished with value: 0.941340629274966 and parameters: {'max_depth': 7, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,778] Trial 13 finished with value: 0.9178659370725034 and parameters: {'max_depth': 2, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 0 with value: 0.941340629274966.
# [I 2025-07-12 22:11:37,820] Trial 14 finished with value: 0.94593707250342 and parameters: {'max_depth': 7, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:37,855] Trial 15 finished with value: 0.94593707250342 and parameters: {'max_depth': 12, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:37,890] Trial 16 finished with value: 0.94593707250342 and parameters: {'max_depth': 12, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:37,925] Trial 17 finished with value: 0.9365800273597813 and parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:37,957] Trial 18 finished with value: 0.934281805745554 and parameters: {'max_depth': 14, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:37,990] Trial 19 finished with value: 0.94593707250342 and parameters: {'max_depth': 20, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:38,026] Trial 20 finished with value: 0.9365800273597813 and parameters: {'max_depth': 11, 'min_samples_leaf': 4, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:38,071] Trial 21 finished with value: 0.94593707250342 and parameters: {'max_depth': 13, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:38,108] Trial 22 finished with value: 0.94593707250342 and parameters: {'max_depth': 11, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:38,144] Trial 23 finished with value: 0.9365800273597813 and parameters: {'max_depth': 17, 'min_samples_leaf': 4, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:38,177] Trial 24 finished with value: 0.94593707250342 and parameters: {'max_depth': 9, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:38,211] Trial 25 finished with value: 0.94593707250342 and parameters: {'max_depth': 13, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:38,253] Trial 26 finished with value: 0.9273050615595075 and parameters: {'max_depth': 5, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:38,288] Trial 27 finished with value: 0.9365800273597813 and parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:38,320] Trial 28 finished with value: 0.941340629274966 and parameters: {'max_depth': 14, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# [I 2025-07-12 22:11:38,367] Trial 29 finished with value: 0.941340629274966 and parameters: {'max_depth': 8, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 14 with value: 0.94593707250342.
# Tiempo de búsqueda: 1.004s

# %% [markdown]
# Podemos consultar los mejores hiperparámetros encontrados y el mejor resultado de validación cruzada:

# %%
best_params = study.best_params
print("Mejores hiperparámetros encontrados por Optuna:")
print(best_params)
print("Mejor score de validación (f1):", study.best_value)
# Out:
# Mejores hiperparámetros encontrados por Optuna:
# {'max_depth': 7, 'min_samples_leaf': 3, 'criterion': 'entropy'}
# Mejor score de validación (f1): 0.94593707250342

# %% [markdown]
# Finalmente, evaluamos el modelo con los mejores parámetros sobre el conjunto de prueba.

# %%
final_model = DecisionTreeClassifier(**best_params, random_state=42)
final_model.fit(X_train, y_train)
y_pred_optuna = final_model.predict(X_test)

print("Accuracy en test (Optuna):", accuracy_score(y_test, y_pred_optuna))
print("F1 Score en test (Optuna):", f1_score(y_test, y_pred_optuna))
# Out:
# Accuracy en test (Optuna): 0.9370629370629371
# F1 Score en test (Optuna): 0.9491525423728814

# %%
print("Modelo final:")
print(final_model)
# Out:
# Modelo final:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, min_samples_leaf=3,
#                        random_state=42)

# %% [markdown]
# También es posible visualizar los resultados del proceso de optimización. Esto nos ayuda a entender cómo evolucionó el score a lo largo de los intentos, y qué hiperparámetros fueron más importantes.

# %%
# Establecer el renderizador a 'browser'
pio.renderers.default = 'browser'

# Ahora sí mostrar el gráfico
import optuna.visualization as vis
vis.plot_optimization_history(study).show()
vis.plot_param_importances(study).show()
